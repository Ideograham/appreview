# %% [markdown]
# # Application Review

# %% [markdown]
# ### 225HP @ 2200

# %%
import pandas as pd
import numpy as np
import scipy
import scipy.fftpack
from scipy.signal import hanning
from nptdms import tdms
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %% [markdown]
# ### Path to TDMS file:

# %%
tdmspath = "./TDMS/vib.tdms"

# %% [markdown]
# ### Constants from Performance Curve

# %%
perf_curve_cac_min = 48  #degrees C
perf_curve_cac_max = 56  #degrees C
perf_curve_max_top_tank = 113 #degrees C

perf_curve_min_water_pump_inlet_95C = 103 #kPa
perf_curve_max_intake_restriction = -3.75 #kPa

# %% [markdown]
# ### Setup Data Structures and Perform Standard calculations

# %%
#create an instance of tdms data from the specified TDMS file
#tdms = dtdms.drivetdms(tdmspath)

tdfile = tdms.TdmsFile(tdmspath)

for channel in tdfile.group_channels('Vibration'):
    print(channel.properties)
    print("\n")

#object().properties
#df = tdfile.as_dataframe()
#df
# Out:
# OrderedDict([('Sensor Sensitivity (mV/EU)', '10.02'), ('Engineering Units', 'g'), ('dB Reference (EU)', '1.00E+0'), ('Custom Label', 'EU'), ('Weighting Filter', 'Linear'), ('Pregain (dB)', '0.00'), ('Sensor SN', '12393X - X Axis'), ('Sensor Cal Date', '9/11/2015'), ('Sensor Cal Due', '9/11/2017'), ('wf_start_time', datetime.datetime(2018, 1, 5, 18, 18, 7, 775881, tzinfo=<UTC>)), ('wf_start_offset', 0.0), ('wf_increment', 0.00011718750000000002), ('wf_samples', 8533), ('Group', 'Vibration'), ('NI_ChannelName', 'DOC X'), ('NI_UnitDescription', 'V'), ('unit_string', 'V')])
#
#
# OrderedDict([('Sensor Sensitivity (mV/EU)', '10.12'), ('Engineering Units', 'g'), ('dB Reference (EU)', '1.00E+0'), ('Custom Label', 'EU'), ('Weighting Filter', 'Linear'), ('Pregain (dB)', '0.00'), ('Sensor SN', '12393Y - Y Axis'), ('Sensor Cal Date', '9/11/2015'), ('Sensor Cal Due', '9/11/2017'), ('wf_start_time', datetime.datetime(2018, 1, 5, 18, 18, 7, 775881, tzinfo=<UTC>)), ('wf_start_offset', 0.0), ('wf_increment', 0.00011718750000000002), ('wf_samples', 8533), ('Group', 'Vibration'), ('NI_ChannelName', 'DOC Y'), ('NI_UnitDescription', 'V'), ('unit_string', 'V')])
#
#
# OrderedDict([('Sensor Sensitivity (mV/EU)', '10.15'), ('Engineering Units', 'g'), ('dB Reference (EU)', '1.00E+0'), ('Custom Label', 'EU'), ('Weighting Filter', 'Linear'), ('Pregain (dB)', '0.00'), ('Sensor SN', '12393Z - Z Axis'), ('Sensor Cal Date', '9/11/2015'), ('Sensor Cal Due', '9/11/2017'), ('wf_start_time', datetime.datetime(2018, 1, 5, 18, 18, 7, 775881, tzinfo=<UTC>)), ('wf_start_offset', 0.0), ('wf_increment', 0.00011718750000000002), ('wf_samples', 8533), ('Group', 'Vibration'), ('NI_ChannelName', 'DOC Z'), ('NI_UnitDescription', 'V'), ('unit_string', 'V')])
#
#
# OrderedDict([('Sensor Sensitivity (mV/EU)', '10.17'), ('Engineering Units', 'g'), ('dB Reference (EU)', '1.00E+0'), ('Custom Label', 'EU'), ('Weighting Filter', 'Linear'), ('Pregain (dB)', '0.00'), ('Sensor SN', '12413X - X Axis'), ('Sensor Cal Date', '9/28/2015'), ('Sensor Cal Due', '9/28/2017'), ('wf_start_time', datetime.datetime(2018, 1, 5, 18, 18, 7, 775881, tzinfo=<UTC>)), ('wf_start_offset', 0.0), ('wf_increment', 0.00011718750000000002), ('wf_samples', 8533), ('Group', 'Vibration'), ('NI_ChannelName', 'SCR X'), ('NI_UnitDescription', 'V'), ('unit_string', 'V')])
#
#
# OrderedDict([('Sensor Sensitivity (mV/EU)', '10.11'), ('Engineering Units', 'g'), ('dB Reference (EU)', '1.00E+0'), ('Custom Label', 'EU'), ('Weighting Filter', 'Linear'), ('Pregain (dB)', '0.00'), ('Sensor SN', '12413Y - Y Axis'), ('Sensor Cal Date', '9/28/2015'), ('Sensor Cal Due', '9/28/2017'), ('wf_start_time', datetime.datetime(2018, 1, 5, 18, 18, 7, 775881, tzinfo=<UTC>)), ('wf_start_offset', 0.0), ('wf_increment', 0.00011718750000000002), ('wf_samples', 8533), ('Group', 'Vibration'), ('NI_ChannelName', 'SCR Y'), ('NI_UnitDescription', 'V'), ('unit_string', 'V')])
#
#
# OrderedDict([('Sensor Sensitivity (mV/EU)', '10.11'), ('Engineering Units', 'g'), ('dB Reference (EU)', '1.00E+0'), ('Custom Label', 'EU'), ('Weighting Filter', 'Linear'), ('Pregain (dB)', '0.00'), ('Sensor SN', '12413Z - Z Axis'), ('Sensor Cal Date', '9/28/2015'), ('Sensor Cal Due', '9/28/2017'), ('wf_start_time', datetime.datetime(2018, 1, 5, 18, 18, 7, 775881, tzinfo=<UTC>)), ('wf_start_offset', 0.0), ('wf_increment', 0.00011718750000000002), ('wf_samples', 8533), ('Group', 'Vibration'), ('NI_ChannelName', 'SCR Z'), ('NI_UnitDescription', 'V'), ('unit_string', 'V')])

# %%
tdfile.group_channels('Vibration')
# Out:
# [<TdmsObject with path /'Vibration'/'DOC X'>,
#  <TdmsObject with path /'Vibration'/'DOC Y'>,
#  <TdmsObject with path /'Vibration'/'DOC Z'>,
#  <TdmsObject with path /'Vibration'/'SCR X'>,
#  <TdmsObject with path /'Vibration'/'SCR Y'>,
#  <TdmsObject with path /'Vibration'/'SCR Z'>]

# %%
data = tdfile.channel_data('Vibration', 'DOC X')
data
dataProp = tdfile.group_channels('Vibration')[0].properties
DOCSensitivity = float(dataProp['Sensor Sensitivity (mV/EU)'])
DOCSensitivity
gData = (data * 1000 / DOCSensitivity)

# %%
df = tdfile.as_dataframe()

# %%
#df

# %%
#Add calculated columns to the base data frame
#df = pd.DataFrame(mL, index=mL['Timestamp'])

#Standard Calculations
#df['Ambient'] = (df.tT01_Ambient_Air_01 + df.tT02_Ambient_Air_02) / 2.0

# %% [markdown]
# ### Plot overall Run.  Look at index at bottom for more detailed plot in next cell.

# %%
df.plot(figsize=(12,24), color=('r'), subplots=True );

# %%
#Convert Data to correct units.  
    #Apply the channel sensitivity.
    #Square the data to get power? g^2/Hz?

N = 8192
T = 1/8533.3333
yf = scipy.fft(gData[1:8192])
w = hanning(N)
ywf = (scipy.fft(gData[:8192])*w)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(yf[1:N//2]), '-b')
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(ywf[1:N//2]), '-r')
plt.legend(['FFT', 'FFT w. window'])
plt.grid()
plt.show()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Window The Data

# %%
#0 Pad The Data

# %% [markdown]
# ### Place the start and end timestamp of the test to be analyzed below
#
# Not all data in the data frame should go into the CAC and temp rise histograms.  Specify only the data where the engine has been warmed up and is running under a representative load for this subset of the data.  Full test runs can be obtained by referening the df data frame instead of this test_subset data frame

# %%
#test_subset = df[800:1550]
#section_plot = test_subset.plot(figsize=(15,30), color = ('g'), subplots=True);

# %% [markdown]
# # Histograms from the test_subset data

# %%
#wpphist.plot(data=test_subset['IntakeTempRise'].values, ylabel='Count', xlabel='Temperature (degC)', 
#             title='Intake Temp Rise (degC) Histogram', color='green')
